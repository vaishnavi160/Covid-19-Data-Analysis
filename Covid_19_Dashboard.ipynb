# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi160/Covid-19-Data-Analysis/blob/main/Covid_19_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **24 January 2022**

# %% [markdown]
# # **COVID 19 DASHBOARD**

# %% [markdown]
# ### *This notebook contains covid 19 data analysis.*</br>
# ### *It contains latest data upto* *Jan* *2022*. *❗*

# %% [markdown]
# ## What is COVID-19?
#
# > Coronaviruses are a large family of viruses that may cause respiratory illnesses in humans ranging from common colds to more severe conditions such as Severe Acute Respiratory Syndrome (SARS) and Middle Eastern Respiratory Syndrome (MERS).1
# 'Novel coronavirus' is a new, previously unidentified strain of coronavirus. The novel coronavirus involved in the current outbreak has been named SARS-CoV-2 by the World Health Organization (WHO). 3The disease it causes has been named “coronavirus disease 2019” (or “COVID-19”).`
#
# ![Coronavirus particle Image](https://www.apta.com/wp-content/uploads/home-banner-1.jpg)

# %% [markdown]
# ### Importing Libraries

# %%
# importing libraries

from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.core.display import display, HTML

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import folium
import plotly.graph_objects as go
import seaborn as sns
import ipywidgets as widgets

# %% [markdown]
# ## Importing Data

# %%
# loading data right from the source:
death_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-02bd2703-7604-4873-a7e7-c9ce164552c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02bd2703-7604-4873-a7e7-c9ce164552c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving country_wise_latest.csv to country_wise_latest (1).csv

# %%
import io
country_df = pd.read_csv(io.BytesIO(uploaded['country_wise_latest.csv']))

# %% [markdown]
# ## Data Analyis

# %%
death_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  1/21/22  1/22/22  1/23/22
# 0            NaN    Afghanistan  33.93911  ...     7390     7390     7393
# 1            NaN        Albania  41.15330  ...     3292     3297     3305
# 2            NaN        Algeria  28.03390  ...     6468     6481     6495
# 3            NaN        Andorra  42.50630  ...      144      144      144
# 4            NaN         Angola -11.20270  ...     1884     1886     1888
#
# [5 rows x 737 columns]

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  1/21/22  1/22/22  1/23/22
# 0            NaN    Afghanistan  33.93911  ...   159516   159548   159649
# 1            NaN        Albania  41.15330  ...   244182   246412   248070
# 2            NaN        Algeria  28.03390  ...   232325   234536   236670
# 3            NaN        Andorra  42.50630  ...    33025    33025    33025
# 4            NaN         Angola -11.20270  ...    95676    95902    96582
#
# [5 rows x 737 columns]

# %%
recovered_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  1/21/22  1/22/22  1/23/22
# 0            NaN    Afghanistan  33.93911  ...        0        0        0
# 1            NaN        Albania  41.15330  ...        0        0        0
# 2            NaN        Algeria  28.03390  ...        0        0        0
# 3            NaN        Andorra  42.50630  ...        0        0        0
# 4            NaN         Angola -11.20270  ...        0        0        0
#
# [5 rows x 737 columns]

# %%
country_df.head()
# Out:
#   Country/Region  Confirmed  ...  1 week % increase             WHO Region
# 0    Afghanistan      36263  ...               2.07  Eastern Mediterranean
# 1        Albania       4880  ...              17.00                 Europe
# 2        Algeria      27973  ...              18.07                 Africa
# 3        Andorra        907  ...               2.60                 Europe
# 4         Angola        950  ...              26.84                 Africa
#
# [5 rows x 15 columns]

# %%
death_df.describe()
# Out:
#               Lat        Long  ...        1/22/22        1/23/22
# count  278.000000  278.000000  ...     280.000000     280.000000
# mean    20.156042   21.788955  ...   19970.371429   19985.664286
# std     25.283318   76.200169  ...   78502.065149   78550.266435
# min    -51.796300 -178.116500  ...       0.000000       0.000000
# 25%      4.643279  -37.713675  ...      32.250000      33.000000
# 50%     21.517170   20.921188  ...     760.500000     760.500000
# 75%     40.393350   84.992575  ...    7405.250000    7407.500000
# max     71.706900  178.065000  ...  865968.000000  866540.000000
#
# [8 rows x 735 columns]

# %% [markdown]
# ## Data Cleaning

# %%
death_df.isnull().sum()
# Out:
# Province/State    193
# Country/Region      0
# Lat                 2
# Long                2
# 1/22/20             0
#                  ...
# 1/19/22             0
# 1/20/22             0
# 1/21/22             0
# 1/22/22             0
# 1/23/22             0
# Length: 737, dtype: int64

# %%
# data cleaning - renaming the columns
country_df.columns = map(str.lower, country_df.columns)
country_df.columns
# Out:
# Index(['country/region', 'confirmed', 'deaths', 'recovered', 'active',
#        'new cases', 'new deaths', 'new recovered', 'deaths / 100 cases',
#        'recovered / 100 cases', 'deaths / 100 recovered',
#        'confirmed last week', '1 week change', '1 week % increase',
#        'who region'],
#       dtype='object')

# %%
recovered_df.columns = map(str.lower, recovered_df.columns)
death_df.columns = map(str.lower, death_df.columns)
confirmed_df.columns = map(str.lower, confirmed_df.columns)

# %%
confirmed_df= confirmed_df.rename(columns={ 'province/state' : 'state' , 'country/region' : 'country'})

# %%
recovered_df = recovered_df.rename(columns={ 'province/state' : 'state' , 'country/region' : 'country'})
death_df = death_df.rename(columns={ 'province/state' : 'state' , 'country/region' : 'country'})
country_df = country_df.rename(columns={ 'province/state' : 'state' , 'country/region' : 'country'})

# %%
sorted_country_df= country_df.sort_values('confirmed' , ascending=False).head(15)

# %%
sorted_country_df
# Out:
#             country  confirmed  ...  1 week % increase             who region
# 173              US    4290259  ...              11.88               Americas
# 23           Brazil    2442375  ...              15.28               Americas
# 79            India    1480073  ...              28.11        South-East Asia
# 138          Russia     816680  ...               5.21                 Europe
# 154    South Africa     452529  ...              21.12                 Africa
# 111          Mexico     395489  ...              13.19               Americas
# 132            Peru     389717  ...               8.96               Americas
# 35            Chile     347923  ...               4.47               Americas
# 177  United Kingdom     301708  ...               1.60                 Europe
# 81             Iran     293606  ...               6.30  Eastern Mediterranean
# 128        Pakistan     274289  ...               3.08  Eastern Mediterranean
# 157           Spain     272421  ...               2.86                 Europe
# 145    Saudi Arabia     268934  ...               6.15  Eastern Mediterranean
# 37         Colombia     257101  ...              26.03               Americas
# 85            Italy     246286  ...               0.68                 Europe
#
# [15 rows x 15 columns]

# %%
confirmed_total = int(country_df['confirmed'].sum())
deaths_total = int(country_df['deaths'].sum())
recovered_total = int(country_df['recovered'].sum())
active_total = int(country_df['active'].sum())

# %%
def highlight_col(x):
  r = 'background-color : red'
  p = 'background-color : purple'
  g = 'background-color : grey'
  temp_df = pd.DataFrame('', index= x.index, columns = x.columns)
  temp_df.iloc[:,1] = p
  temp_df.iloc[:,2] = r
  temp_df.iloc[:,3] = g
  return temp_df
sorted_country_df.style.apply(highlight_col, axis = None)
# Out:
# <style  type="text/css" >
# #T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row2_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row3_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row4_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row5_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row6_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row7_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row8_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row9_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row10_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row11_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row12_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row13_col1,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row14_col1{
#             background-color :  purple;
#         }#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row2_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row3_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row4_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row5_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row6_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row7_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row8_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row9_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row10_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row11_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row12_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row13_col2,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row14_col2{
#             background-color :  red;
#         }#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row2_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row3_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row4_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row5_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row6_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row7_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row8_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row9_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row10_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row11_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row12_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row13_col3,#T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row14_col3{
#             background-color :  grey;
#         }</style><table id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >confirmed</th>        <th class="col_heading level0 col2" >deaths</th>        <th class="col_heading level0 col3" >recovered</th>        <th class="col_heading level0 col4" >active</th>        <th class="col_heading level0 col5" >new cases</th>        <th class="col_heading level0 col6" >new deaths</th>        <th class="col_heading level0 col7" >new recovered</th>        <th class="col_heading level0 col8" >deaths / 100 cases</th>        <th class="col_heading level0 col9" >recovered / 100 cases</th>        <th class="col_heading level0 col10" >deaths / 100 recovered</th>        <th class="col_heading level0 col11" >confirmed last week</th>        <th class="col_heading level0 col12" >1 week change</th>        <th class="col_heading level0 col13" >1 week % increase</th>        <th class="col_heading level0 col14" >who region</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002level0_row0" class="row_heading level0 row0" >173</th>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col0" class="data row0 col0" >US</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col1" class="data row0 col1" >4290259</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col2" class="data row0 col2" >148011</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col3" class="data row0 col3" >1325804</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col4" class="data row0 col4" >2816444</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col5" class="data row0 col5" >56336</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col6" class="data row0 col6" >1076</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col7" class="data row0 col7" >27941</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col8" class="data row0 col8" >3.450000</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col9" class="data row0 col9" >30.900000</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col10" class="data row0 col10" >11.160000</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col11" class="data row0 col11" >3834677</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col12" class="data row0 col12" >455582</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col13" class="data row0 col13" >11.880000</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row0_col14" class="data row0 col14" >Americas</td>
#             </tr>
#             <tr>
#                         <th id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002level0_row1" class="row_heading level0 row1" >23</th>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col0" class="data row1 col0" >Brazil</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col1" class="data row1 col1" >2442375</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col2" class="data row1 col2" >87618</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col3" class="data row1 col3" >1846641</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col4" class="data row1 col4" >508116</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col5" class="data row1 col5" >23284</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col6" class="data row1 col6" >614</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col7" class="data row1 col7" >33728</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col8" class="data row1 col8" >3.590000</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col9" class="data row1 col9" >75.610000</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col10" class="data row1 col10" >4.740000</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col11" class="data row1 col11" >2118646</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col12" class="data row1 col12" >323729</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col13" class="data row1 col13" >15.280000</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row1_col14" class="data row1 col14" >Americas</td>
#             </tr>
#             <tr>
#                         <th id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002level0_row2" class="row_heading level0 row2" >79</th>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row2_col0" class="data row2 col0" >India</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row2_col1" class="data row2 col1" >1480073</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row2_col2" class="data row2 col2" >33408</td>
#                         <td id="T_51b5959c_7ce3_11ec_ac1d_0242ac1c0002row2_col3" class="data row2 col3" >951166</td>
#                         <td id

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### **Graph for confirmed cases according to countries.**

# %%
fig = px.scatter(sorted_country_df.head(10) , x= 'country', y='confirmed', size = 'confirmed', 
                 color= 'country' , hover_name = "country", size_max=55,title = 'COVID World Status', width=1000, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="10507938-7a43-4a2a-bed6-a0f70de35955" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("10507938-7a43-4a2a-bed6-a0f70de35955")) {
#                     Plotly.newPlot(
#                         '10507938-7a43-4a2a-bed6-a0f70de35955',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["US"], "legendgroup": "country=US", "marker": {"color": "#636efa", "size": [4290259], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=US", "showlegend": true, "type": "scatter", "x": ["US"], "xaxis": "x", "y": [4290259], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["Brazil"], "legendgroup": "country=Brazil", "marker": {"color": "#EF553B", "size": [2442375], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=Brazil", "showlegend": true, "type": "scatter", "x": ["Brazil"], "xaxis": "x", "y": [2442375], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["India"], "legendgroup": "country=India", "marker": {"color": "#00cc96", "size": [1480073], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=India", "showlegend": true, "type": "scatter", "x": ["India"], "xaxis": "x", "y": [1480073], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["Russia"], "legendgroup": "country=Russia", "marker": {"color": "#ab63fa", "size": [816680], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=Russia", "showlegend": true, "type": "scatter", "x": ["Russia"], "xaxis": "x", "y": [816680], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["South Africa"], "legendgroup": "country=South Africa", "marker": {"color": "#FFA15A", "size": [452529], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=South Africa", "showlegend": true, "type": "scatter", "x": ["South Africa"], "xaxis": "x", "y": [452529], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["Mexico"], "legendgroup": "country=Mexico", "marker": {"color": "#19d3f3", "size": [395489], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=Mexico", "showlegend": true, "type": "scatter", "x": ["Mexico"], "xaxis": "x", "y": [395489], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["Peru"], "legendgroup": "country=Peru", "marker": {"color": "#FF6692", "size": [389717], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=Peru", "showlegend": true, "type": "scatter", "x": ["Peru"], "xaxis": "x", "y": [389717], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["Chile"], "legendgroup": "country=Chile", "marker": {"color": "#B6E880", "size": [347923], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=Chile", "showlegend": true, "type": "scatter", "x": ["Chile"], "xaxis": "x", "y": [347923], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.size}", "hovertext": ["United Kingdom"], "legendgroup": "country=United Kingdom", "marker": {"color": "#FF97FF", "size": [301708], "sizemode": "area", "sizeref": 1418.267438016529, "symbol": "circle"}, "mode": "markers", "name": "country=United Kingdom", "showlegend": true, "type": "scatter", "x": ["Un ...
#                         {"height": 500, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar

# %% [markdown]
# **From this we can observe US is at top amongst all the countries for confirmed cases.**

# %% [markdown]
# ## **Graph for confirmed cases and deaths.**

# %%
fig1 = px.scatter(sorted_country_df.head(10) , x= 'country', y='confirmed', size = 'deaths', 
                 color= 'confirmed' , hover_name = "country", size_max=60, title = 'COVID World Status')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2b40f5ec-e7ca-402b-af78-8743a7180158" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2b40f5ec-e7ca-402b-af78-8743a7180158")) {
#                     Plotly.newPlot(
#                         '2b40f5ec-e7ca-402b-af78-8743a7180158',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.color}<br>deaths=%{marker.size}", "hovertext": ["US", "Brazil", "India", "Russia", "South Africa", "Mexico", "Peru", "Chile", "United Kingdom", "Iran"], "legendgroup": "", "marker": {"color": [4290259, 2442375, 1480073, 816680, 452529, 395489, 389717, 347923, 301708, 293606], "coloraxis": "coloraxis", "size": [148011, 87618, 33408, 13334, 7067, 44022, 18418, 9187, 45844, 15912], "sizemode": "area", "sizeref": 41.11416666666667, "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["US", "Brazil", "India", "Russia", "South Africa", "Mexico", "Peru", "Chile", "United Kingdom", "Iran"], "xaxis": "x", "y": [4290259, 2442375, 1480073, 816680, 452529, 395489, 389717, 347923, 301708, 293606], "yaxis": "y"}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "confirmed"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"ma ...

# %% [markdown]
# ## **Graph for confirmed cases and recovered.**

# %%
fig2 = px.scatter(sorted_country_df.head(10) , x= 'country', y='confirmed', size = 'recovered', 
                 color= 'confirmed' , hover_name = "country", size_max=60, title = 'COVID World Status')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c398a306-c5be-4f9b-bc99-1113ed6e1443" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c398a306-c5be-4f9b-bc99-1113ed6e1443")) {
#                     Plotly.newPlot(
#                         'c398a306-c5be-4f9b-bc99-1113ed6e1443',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>country=%{x}<br>confirmed=%{marker.color}<br>recovered=%{marker.size}", "hovertext": ["US", "Brazil", "India", "Russia", "South Africa", "Mexico", "Peru", "Chile", "United Kingdom", "Iran"], "legendgroup": "", "marker": {"color": [4290259, 2442375, 1480073, 816680, 452529, 395489, 389717, 347923, 301708, 293606], "coloraxis": "coloraxis", "size": [1325804, 1846641, 951166, 602249, 274925, 303810, 272547, 319954, 1437, 255144], "sizemode": "area", "sizeref": 512.9558333333333, "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["US", "Brazil", "India", "Russia", "South Africa", "Mexico", "Peru", "Chile", "United Kingdom", "Iran"], "xaxis": "x", "y": [4290259, 2442375, 1480073, 816680, 452529, 395489, 389717, 347923, 301708, 293606], "yaxis": "y"}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "confirmed"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"ma ...

# %% [markdown]
# **This graph depicts that even Brazil has 2nd highest no. of confirmed cases its recovery rate is higgest.**

# %% [markdown]
# ## **Line chart for Confirmed cases and Deaths**

# %% [markdown]
# **Enter the country name for respective status.**

# %%
def plot_cases_for_country(country):

  labels =[' comfirmed' , 'deaths']
  colors = ['blue', 'red']
  mode_size = [6,8]
  line_size = [4,5]
  df_list =[confirmed_df, death_df]
  fig = go.Figure()

  for i, df in enumerate(df_list):
    if country == 'World' or country == 'world':
      x_data = np.array(list(df.iloc[:, 5:].columns))
      y_data = np.sum(np.asarray(df.iloc[:,5:]), axis = 0)
    else:
      x_data = np.array(list(df.iloc[:, 5:].columns))
      y_data = np.sum(np.asarray(df[df['country']==country].iloc[:, 5:]), axis=0)

    fig.add_trace(go.Scatter(x=x_data, y=y_data, mode = 'lines+markers', 
                             name = labels[i],
                             line = dict(color = colors[i] , width = line_size[i]), 
                             connectgaps = True,
                             text = 'Total' + str(labels[i])+ ": " + str(y_data[-1])
                            ))
  
  fig.show()
  
#plot_cases_for_country('China')
interact(plot_cases_for_country, country='World');
# Out:
# interactive(children=(Text(value='World', description='country'), Output()), _dom_classes=('widget-interact',)…

# %% [markdown]
# ## **10 Worst affected countries**

# %%
px.bar(
    sorted_country_df.head(10),
    x = "country",
    y = "confirmed",
    title= "Top 10 worst affected countries (confirmed cases)", # the axis names
    color_discrete_sequence=["indigo"], 
    height=500,
    width=800
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ee150c6-1fe3-4823-8ec4-a568178c6c45" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ee150c6-1fe3-4823-8ec4-a568178c6c45")) {
#                     Plotly.newPlot(
#                         '1ee150c6-1fe3-4823-8ec4-a568178c6c45',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "country=%{x}<br>confirmed=%{y}", "legendgroup": "", "marker": {"color": "indigo"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["US", "Brazil", "India", "Russia", "South Africa", "Mexico", "Peru", "Chile", "United Kingdom", "Iran"], "xaxis": "x", "y": [4290259, 2442375, 1480073, 816680, 452529, 395489, 389717, 347923, 301708, 293606], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %%
px.bar(
    sorted_country_df.head(10),
    x = "country",
    y = "deaths",
    title= "Top 10 worst affected countries (deaths)", # the axis names
    color_discrete_sequence=["red"], 
    height=500,
    width=800
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2ec6b551-24eb-4e9b-94e3-f235527f09b6" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2ec6b551-24eb-4e9b-94e3-f235527f09b6")) {
#                     Plotly.newPlot(
#                         '2ec6b551-24eb-4e9b-94e3-f235527f09b6',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "country=%{x}<br>deaths=%{y}", "legendgroup": "", "marker": {"color": "red"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["US", "Brazil", "India", "Russia", "South Africa", "Mexico", "Peru", "Chile", "United Kingdom", "Iran"], "xaxis": "x", "y": [148011, 87618, 33408, 13334, 7067, 44022, 18418, 9187, 45844, 15912], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %%
px.bar(
    sorted_country_df.head(10),
    x = "country",
    y = "recovered",
    title= "Top 10 worst affected countries (recovery status)", # the axis names
    color_discrete_sequence=["green"], 
    height=500,
    width=800
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b586e2ea-389f-4ba2-ad4f-791dba0fd32d" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b586e2ea-389f-4ba2-ad4f-791dba0fd32d")) {
#                     Plotly.newPlot(
#                         'b586e2ea-389f-4ba2-ad4f-791dba0fd32d',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "country=%{x}<br>recovered=%{y}", "legendgroup": "", "marker": {"color": "green"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["US", "Brazil", "India", "Russia", "South Africa", "Mexico", "Peru", "Chile", "United Kingdom", "Iran"], "xaxis": "x", "y": [1325804, 1846641, 951166, 602249, 274925, 303810, 272547, 319954, 1437, 255144], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %% [markdown]
# ## **WORLD MAP**

# %%
world_map = folium.Map(location=[11,0],tiles='cartodbpositron', zoom_start=2, max_zoom=6, min_zoom=2 )
loc = 'WORLD STATUS OF CORONA OUTBREAK'
title_html = '''
             <h2 align="center" style="font-size:20px"><b>{}</b></h2>
             '''.format(loc)
world_map.get_root().html.add_child(folium.Element(title_html))
for i in range(len(confirmed_df)):
  folium.Circle(
  location = [confirmed_df.iloc[i]['lat'], confirmed_df.iloc[i]['long']],
     
  fill = True,
  radius = (int ((np.log(confirmed_df.iloc[i,-1]+1.00001))) + 0.2)*50000,
  fill_color = 'blue',
  tooltip = "<div style='margin: 0; background-color: black; color: white;'>"+
                    "<h4 style='text-align:center;font-weight: bold'>"+confirmed_df.iloc[i]['country'] + "</h4>"
                    "<hr style='margin:10px;color: white;'>"+
                    "<ul style='color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px'>"+
                        "<li>Confirmed: "+str(confirmed_df.iloc[i,-1])+"</li>"+
                        "<li>Deaths:   "+str(death_df.iloc[i,-1])+"</li>"+
                        "<li>Death Rate: "+ str(np.round(death_df.iloc[i,-1]/(confirmed_df.iloc[i,-1]+1.00001)*100,2))+ "</li>"+
                    "</ul></div>",
  color = 'red',
  ).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_f5c3a97b3d6847929e93add1bb47d70e%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%3Ch2%20align%3D%22center%22%20style%3D%22font-size%3A20px%22%3E%3Cb%3EWORLD%20STATUS%20OF%20CORONA%20OUTBREAK%3C/b%3E%3C/h2%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f5c3a97b3d6847929e93add1bb47d70e%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_f5c3a97b3d6847929e93add1bb47d70e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_f5c3a97b3d6847929e93add1bb47d70e%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B11%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%202%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_65774bd7f0d44c6a873e4da02ed86859%20%3D%20L.tileLayer%28 ...

# %%
# displaying the total stats

display(HTML("<div style = 'background-color: #504e4e; padding: 30px '>" +
             "<span style='color: #fff; font-size:30px;'> Confirmed: "  + str(confirmed_total) +"</span>" +
             "<span style='color: red; font-size:30px;margin-left:20px;'> Deaths: " + str(deaths_total) + "</span>"+
             "<span style='color: lightgreen; font-size:30px; margin-left:20px;'> Recovered: " + str(recovered_total) + "</span>"+
             "</div>")
       )
# Out:
# <div style = 'background-color: #504e4e; padding: 30px '><span style='color: #fff; font-size:30px;'> Confirmed: 16480485</span><span style='color: red; font-size:30px;margin-left:20px;'> Deaths: 654036</span><span style='color: lightgreen; font-size:30px; margin-left:20px;'> Recovered: 9468087</span></div>
